# %% [markdown]
# # Purpose of script
#
# The purpose of this script is to aggregate Google API data from daily dfs.
#
# For example, our current approach (outlined in 'examine_google_trends_API.ipynb') exports the daily Google Trends data as separate .csv files, for each date. We need to aggregate these dates into one df

# %%
import os
import pandas as pd
import datetime
import boto3

# %% [markdown]
# # General Approach
#
# The general approach should look like this:
#
# 1. Connect with AWS
# 2. Use a for loop to iterate through the files in AWS
# - They all either begin with `interest_over_time_` or `interest_by_region_`, followed by a date (e.g., 2020-03-20)
# - Read in all the files from AWS, store a local version
# - Read in the local version as a pandas df, delete local version
# - Append the new pandas df to a running pandas df
# 3. Export the pandas df, with the name indicating the earliest and latest dates in that df (e.g., `interest_over_time_2020-03-01_2021-02-01.csv`. Export locally, then to AWS, then delete local version.

# %% [markdown]
# Once we make the first compiled version, subsequent compiled versions just need to append to the latest compiled version.

# %% [markdown]
# #### Initialize constants

# %%
KEYWORDS = ["covid", "coronavirus", "lockdown", "quarantine", "vaccine"]

# %%
AWS_BUCKET = os.environ["AWS_BUCKET"]
AWS_ACCESS = os.environ["AWS_ACCESS"]
AWS_SECRET = os.environ["AWS_SECRET"]

# %%
FRESH_SCRAPES_FILENAME = ""
INTEREST_OVER_TIME_FILENAME = "interest_over_time_"
INTEREST_BY_REGION_FILENAME = "interest_by_region_"

LOCAL_SCRAPES_DIR = "../../../tweets/google_API_scrapes/"
AWS_SCRAPES_DIR = "google_API_scrapes/"

LOCAL_TIME_FILENAME = LOCAL_SCRAPES_DIR + INTEREST_OVER_TIME_FILENAME
LOCAL_REGION_FILENAME = LOCAL_SCRAPES_DIR + INTEREST_BY_REGION_FILENAME

AWS_TIME_FILENAME = AWS_SCRAPES_DIR + INTEREST_OVER_TIME_FILENAME
AWS_REGION_FILENAME = AWS_SCRAPES_DIR + INTEREST_BY_REGION_FILENAME

# %% [markdown]
# #### Connect with AWS S3 instance

# %%
s3 = boto3.client('s3',
                  aws_access_key_id=AWS_ACCESS,
                  aws_secret_access_key=AWS_SECRET)

# %% [markdown]
# #### Download one file, as a test
#
# Download one `interest_over_time_` file, as a test

# %%
TEST_DATE = "2020-10-15"

# %%
AWS_TIME_FILENAME + TEST_DATE + ".csv"
# Out:
# 'google_API_scrapes/interest_over_time_2020-10-15.csv'

# %%
s3.download_file(Bucket=AWS_BUCKET, 
                 Key= AWS_TIME_FILENAME + TEST_DATE + ".csv", 
                 Filename=LOCAL_TIME_FILENAME + TEST_DATE + ".csv")

# %%
time_df = pd.read_csv(LOCAL_TIME_FILENAME + TEST_DATE + ".csv")

# %%
time_df.head()
# Out:
#          date  covid  coronavirus  lockdown  quarantine  vaccine  isPartial
# 0  2020-10-15    100           32         1           4        7      False

# %%
os.remove(LOCAL_TIME_FILENAME + TEST_DATE + ".csv")

# %%
# create an aggregate df
time_aggregate_df = pd.DataFrame(columns = ['date', 'covid', 'coronavirus', 
                                       'lockdown', 'quarantine', 
                                       'vaccine','isPartial'])

# %% [markdown]
# ASIDE: doing the same steps, but for `region` data

# %%
s3.download_file(Bucket=AWS_BUCKET, 
                 Key= AWS_REGION_FILENAME + TEST_DATE + ".csv", 
                 Filename=LOCAL_REGION_FILENAME + TEST_DATE + ".csv")

# %%
region_df = pd.read_csv(LOCAL_REGION_FILENAME + TEST_DATE + ".csv")

# %%
region_df.head()
# Out:
#       geoName  covid  coronavirus  lockdown  quarantine  vaccine
# 0     Alabama     75           21         0           1        3
# 1      Alaska     77           16         0           0        7
# 2     Arizona     64           29         0           2        5
# 3    Arkansas     71           21         2           0        6
# 4  California     69           22         1           2        6

# %%
region_df.columns
# Out:
# Index(['geoName', 'covid', 'coronavirus', 'lockdown', 'quarantine', 'vaccine'], dtype='object')

# %%
# create an aggregate df
region_aggregate_df = pd.DataFrame(columns = ['geoName', 'covid', 'coronavirus', 
                                              'lockdown', 'quarantine', 'vaccine', 'date'])

# %%
# add date column to region_df
region_df["date"] = TEST_DATE

# %%
region_df.head()
# Out:
#       geoName  covid  coronavirus  lockdown  quarantine  vaccine        date
# 0     Alabama     75           21         0           1        3  2020-10-15
# 1      Alaska     77           16         0           0        7  2020-10-15
# 2     Arizona     64           29         0           2        5  2020-10-15
# 3    Arkansas     71           21         2           0        6  2020-10-15
# 4  California     69           22         1           2        6  2020-10-15

# %% [markdown]
# Append to df

# %%
aggregate_df = aggregate_df.append(df)

# %%
aggregate_df
# Out:
#          date covid coronavirus lockdown quarantine vaccine isPartial
# 0  2020-10-15   100          32        1          4       7     False

# %% [markdown]
# ### Loop through dates
#
# Now that we know that this works for one script, let's do this for all the files. We have data from `2020-03-01` to `2021-02-14` (this script was created on `2021-02-15`)

# %%
start_date = datetime.date(2020, 3, 1)
end_date = datetime.date(2021, 2, 15)
total_num_dates = (end_date - start_date).days

# %%
dates_arr = []

# %%
for day in range(total_num_dates):
    new_date = (start_date + datetime.timedelta(days = day)).isoformat()
    dates_arr.append(new_date)

# %%
dates_arr[-1]
# Out:
# '2021-02-14'

# %% [markdown]
# ### Create for-loop script

# %% [markdown]
# Create aggregate dfs to hold time and region data

# %%
time_aggregate_df = pd.DataFrame(columns = ['date', 'covid', 'coronavirus', 
                                           'lockdown', 'quarantine', 
                                           'vaccine','isPartial'])

region_aggregate_df = pd.DataFrame(columns = ['geoName', 'covid', 'coronavirus', 
                                              'lockdown', 'quarantine', 'vaccine', 'date'])

# %%
for date in dates_arr:
    
    try:
        
        print(f"Getting Google API trends data (saved in AWS) for {date}")

        # load from AWS, save locally
        s3.download_file(Bucket=AWS_BUCKET, 
                         Key= AWS_TIME_FILENAME + date + ".csv", 
                         Filename=LOCAL_TIME_FILENAME + date + ".csv")

        s3.download_file(Bucket=AWS_BUCKET, 
                         Key= AWS_REGION_FILENAME + date + ".csv", 
                         Filename=LOCAL_REGION_FILENAME + date + ".csv")
        
        # read as csv
        time_df = pd.read_csv(LOCAL_TIME_FILENAME + date + ".csv")
        region_df = pd.read_csv(LOCAL_REGION_FILENAME + date + ".csv")

        # delete local versions of the file
        os.remove(LOCAL_TIME_FILENAME + date + ".csv")
        os.remove(LOCAL_REGION_FILENAME + date + ".csv")
        
        # for time df, append directly to aggregate. For region df, add 'date' column
        time_aggregate_df = time_aggregate_df.append(time_df)
        
        region_df["date"] = date
        region_aggregate_df = region_aggregate_df.append(region_df)
        
        print(f"Finished appending Google API trends data for {date}")
        
    except Exception as e:
        print("Error in appending Google API trends data")
        print(e)
        print(f"Error occurred for the following date: {date}")
# Out:
# Getting Google API trends data (saved in AWS) for 2020-03-01
# Finished appending Google API trends data for 2020-03-01
# Getting Google API trends data (saved in AWS) for 2020-03-02
# Finished appending Google API trends data for 2020-03-02
# Getting Google API trends data (saved in AWS) for 2020-03-03
# Finished appending Google API trends data for 2020-03-03
# Getting Google API trends data (saved in AWS) for 2020-03-04
# Finished appending Google API trends data for 2020-03-04
# Getting Google API trends data (saved in AWS) for 2020-03-05
# Finished appending Google API trends data for 2020-03-05
# Getting Google API trends data (saved in AWS) for 2020-03-06
# Finished appending Google API trends data for 2020-03-06
# Getting Google API trends data (saved in AWS) for 2020-03-07
# Finished appending Google API trends data for 2020-03-07
# Getting Google API trends data (saved in AWS) for 2020-03-08
# Finished appending Google API trends data for 2020-03-08
# Getting Google API trends data (saved in AWS) for 2020-03-09
# Finished appending Google API trends data for 2020-03-09
# Getting Google API trends data (saved in AWS) for 2020-03-10
# Finished appending Google API trends data for 2020-03-10
# Getting Google API trends data (saved in AWS) for 2020-03-11
# Finished appending Google API trends data for 2020-03-11
# Getting Google API trends data (saved in AWS) for 2020-03-12
# Finished appending Google API trends data for 2020-03-12
# Getting Google API trends data (saved in AWS) for 2020-03-13
# Finished appending Google API trends data for 2020-03-13
# Getting Google API trends data (saved in AWS) for 2020-03-14
# Finished appending Google API trends data for 2020-03-14
# Getting Google API trends data (saved in AWS) for 2020-03-15
# Finished appending Google API trends data for 2020-03-15
# Getting Google API trends data (saved in AWS) for 2020-03-16
# Finished appending Google API trends data for 2020-03-16
# Getting Google API trends data (saved in AWS) for 2020-03-17
# Finished appending Google API trends data for 2020-03-17
# Getting Google API trends data (saved in AWS) for 2020-03-18
# Finished appending Google API trends data for 2020-03-18
# Getting Google API trends data (saved in AWS) for 2020-03-19
# Finished appending Google API trends data for 2020-03-19
# Getting Google API trends data (saved in AWS) for 2020-03-20
# Finished appending Google API trends data for 2020-03-20
# Getting Google API trends data (saved in AWS) for 2020-03-21
# Finished appending Google API trends data for 2020-03-21
# Getting Google API trends data (saved in AWS) for 2020-03-22
# Finished appending Google API trends data for 2020-03-22
# Getting Google API trends data (saved in AWS) for 2020-03-23
# Finished appending Google API trends data for 2020-03-23
# Getting Google API trends data (saved in AWS) for 2020-03-24
# Finished appending Google API trends data for 2020-03-24
# Getting Google API trends data (saved in AWS) for 2020-03-25
# Finished appending Google API trends data for 2020-03-25
# Getting Google API trends data (saved in AWS) for 2020-03-26
# Finished appending Google API trends data for 2020-03-26
# Getting Google API trends data (saved in AWS) for 2020-03-27
# Finished appending Google API trends data for 2020-03-27
# Getting Google API trends data (saved in AWS) for 2020-03-28
# Finished appending Google API trends data for 2020-03-28
# Getting Google API trends data (saved in AWS) for 2020-03-29
# Finished appending Google API trends data for 2020-03-29
# Getting Google API trends data (saved in AWS) for 2020-03-30
# Finished appending Google API trends data for 2020-03-30
# Getting Google API trends data (saved in AWS) for 2020-03-31
# Finished appending Google API trends data for 2020-03-31
# Getting Google API trends data (saved in AWS) for 2020-04-01
# Finished appending Google API trends data for 2020-04-01
# Getting Google API trends data (saved in AWS) for 2020-04-02
# Finished appending Google API trends data for 2020-04-02
# Getting Google API trends data (saved in AWS) for 2020-04-03
# Finished appending Google API trends data for 2020-04-03
# Getting Google API trends data (saved in AWS) for 2020-04-04
# Finished appending Google API trends data for 2020-04-04
# Getting Google API trends data (saved in AWS) for 2020-04-05
# Finished appending Google API trends data for 2020-04-05
# Getting Google API trends data (saved in AWS) for 2020-04-06
# Finished appending Google API trends data for 2020-04-06
# Getting Google API trends data (saved in AWS) for 2020-04-07
# Finished appending Google API trends data for 2020-04-07
# Getting Google API trends data (saved in AWS) for 2020-04-08
# Finished appending Google API trends data for 2020-04-08
# Getting Google API trends data (saved in AWS) for 2020-04-09
# Finished appending Google API trends data for 2020-04-09
# Getting Google API trends data (saved in AWS) for 2020-04-10
# Finished appending Google API trends data for 2020-04-10
# Getting Google API trends data (saved in AWS) for 2020-04-11
# Finished appending Google API trends data for 2020-04-11
# Getting Google API trends data (saved in AWS) for 2020-04-12
# Finished appending Google API trends data for 2020-04-12
# Getting Google API trends data (saved in AWS) for 2020-04-13
# Finished appending Google API trends data for 2020-04-13
# Getting Google API trends data (saved in AWS) for 2020-04-14
# Finished appending Google API trends data for 2020-04-14
# Getting Google API trends data (saved in AWS) for 2020-04-15
# Finished appending Google API trends data for 2020-04-15
# Getting Google API trends data (saved in AWS) for 2020-04-16
# Finished appending Google API trends data for 2020-04-16
# Getting Google API trends data (saved in AWS) for 2020-04-17
# Finished appending Google API trends data for 2020-04-17
# Getting Google API trends data (saved in AWS) for 2020-04-18
# Finished appending Google API trends data for 2020-04-18
# Getting Google API trends data (saved in AWS) for 2020-04-19
# Finished appending Google API trends data for 2020-04-19
# Getting Google API trends data (saved in AWS) for 2020-04-20
# Finished appending Google API trends data for 2020-04-20
# Getting Google API trends data (saved in AWS) for 2020-04-21
# Finished appending Google API trends data for 2020-04-21
# Getting Google API trends data (saved in AWS) for 2020-04-22
# Finished appending Google API trends data for 2020-04-22
# Getting Google API trends data (saved in AWS) for 2020-04-23
# Finished appending Google API trends data for 2020-04-23
# Getting Google API trends data (saved in AWS) for 2020-04-24
# Finished appending Google API trends data for 2020-04-24
# Getting Google API trends data (saved in AWS) for 2020-04-25
# Finished appending Google API trends data for 2020-04-25
# Getting Google API trends data (saved in AWS) for 2020-04-26
# Finished appending Google API trends data for 2020-04-26
# Getting Google API trends data (saved in AWS) for 2020-04-27
# Finished appending Google API trends data for 2020-04-27
# Getting Google API trends data (saved in AWS) for 2020-04-28
# Finished appending Google API trends data for 2020-04-28
# Getting Google API trends data (saved in AWS) for 2020-04-29
# Finished appending Google API trends data for 2020-04-29
# Getting Google API trends data (saved in AWS) for 2020-04-30
# Finished appending Google API trends data for 2020-04-30
# Getting Google API trends data (saved in AWS) for 2020-05-01
# Finished appending Google API trends data for 2020-05-01
# Getting Google API trends data (saved in AWS) for 2020-05-02
# Finished appending Google API trends data for 2020-05-02
# Getting Google API trends data (saved in AWS) for 2020-05-03
# Finished appending Google API trends data for 2020-05-03
# Getting Google API trends data (saved in AWS) for 2020-05-04
# Finished appending Google API trends data for 2020-05-04
# Getting Google API trends data (saved in AWS) for 2020-05-05
# Finished appending Google API trends data for 2020-05-05
# Getting Google API trends data (saved in AWS) for 2020-05-06
# Finished appending Google API trends data for 2020-05-06
# Getting Google API trends data (saved in AWS) for 2020-05-07
# Finished appending Google API trends data for 2020-05-07
# Getting Google API trends data (saved in AWS) for 2020-05-08
# Finished appending Google API trends data for 2020-05-08
# Getting Google API trends data (saved in AWS) for 2020-05-09
# Finished appending Google API trends data for 2020-05-09
# Getting Google API trends data (saved in AWS) for 2020-05-10
# Finished appending Google API trends data for 2020-05-10
# Getting Google API trends data (saved in AWS) for 2020-05-11
# Finished appending Google API trends data for 2020-05-11
# Getting Google API trends data (saved in AWS) for 2020-05-12
# Finished appending Google API trends data for 2020-05-12
# Getting Google API trends data (saved in AWS) for 2020-05-13
# Finished appending Google API trends data for 2020-05-13
# Getting Google API trends data (saved in AWS) for 2020-05-14
# Finished appending Google API trends data for 2020-05-14
# Getting Google API trends data (saved in AWS) for 2020-05-15
# Finished appending Google API trends data for 2020-05-15
# Getting Google API trends data (saved in AWS) for 2020-05-16
# Finished appending Google API trends data for 2020-05-16
# Getting Google API trends data (saved in AWS) for 2020-05-17
# Finished appending Google API trends data for 2020-05-17
# Getting Google API trends data (saved in AWS) for 2020-05-18
# Finished appending Google API trends data for 2020-05-18
# Getting Google API trends data (saved in AWS) for 2020-05-19
# Finished appending Google API trends data for 2020-05-19
# Getting Google API trends data (saved in AWS) for 2020-05-20
# Finished appending Google API trends data for 2020-05-20
# Getting Google API trends data (saved in AWS) for 2020-05-21
# Finished appending Google API trends data for 2020-05-21
# Getting Google API trends data (saved in AWS) for 2020-05-22
# Finished appending Google API trends data for 2020-05-22
# Getting Google API trends data (saved in AWS) for 2020-05-23
# Finished appending Google API trends data for 2020-05-23
# Getting Google API trends data (saved in AWS) for 2020-05-24
# Finished appending Google API trends data for 2020-05-24
# Getting Google API trends data (saved in AWS) for 2020-05-25
# Finished appending Google API trends data for 2020-05-25
# Getting Google API trends data (saved in AWS) for 2020-05-26
# Finished appending Google API trends data for 2020-05-26
# Getting Google API trends data (saved in AWS) for 2020-05-27
# Finished appending Google API trends data for 2020-05-27
# Getting Google API trends data (saved in AWS) for 2020-05-28
# Finished appending Google API trends data for 2020-05-28
# Getting Google API trends data (saved in AWS) for 2020-05-29
# Finished appending Google API trends data for 2020-05-29
# Getting Google API trends data (saved in AWS) for 2020-05-30
# Finished appending Google API trends data for 2020-05-30
# Getting Google API trends data (saved in AWS) for 2020-05-31
# Finished appending Google API trends data for 2020-05-31
# Getting Google API trends data (saved in AWS) for 2020-06-01
# Finished appending Google API trends data for 2020-06-01
# Getting Google API trends data (saved in AWS) for 2020-06-02
# Finished appending Google API trends data for 2020-06-02
# Getting Google API trends data (saved in AWS) for 2020-06-03
# Finished appending Google API trends data for 2020-06-03
# Getting Google API trends data (saved in AWS) for 2020-06-04
# Finished appending Google API trends data for 2020-06-04
# Getting Google API trends data (saved in AWS) for 2020-06-05
# Finished appending Google API trends data for 2020-06-05
# Getting Google API trends data (saved in AWS) for 2020-06-06
# Finished appending Google API trends data for 2020-06-06
# Getting Google API trends data (saved in AWS) for 2020-06-07
# Finished appending Google API trends data for 2020-06-07
# Getting Google API trends data (saved in AWS) for 2020-06-08
# Finished appending Google API trends data for 2020-06-08
# Getting Google API trends data (saved in AWS) for 2020-06-09
# Finished appending Google API trends data for 2020-06-09
# Getting Google API trends data (saved in AWS) for 2020-06-10
# Finished appending Google API trends data for 2020-06-10
# Getting Google API trends data (saved in AWS) for 2020-06-11
# Finished appending Google API trends data for 2020-06-11
# Getting Google API trends data (saved in AWS) for 2020-06-12
# Finished appending Google API trends data for 2020-06-12
# Getting Google API trends data (saved in AWS) for 2020-06-13
# Finished appending Google API trends data for 2020-06-13
# Getting Google API trends data (saved in AWS) for 2020-06-14
# Finished appending Google API trends data for 2020-06-14
# Getting Google API trends data (saved in AWS) for 2020-06-15
# Finished appending Google API trends data for 2020-06-15
# Getting Google API trends data (saved in AWS) for 2020-06-16
# Finished appending Google API trends data for 2020-06-16
# Getting Google API trends data (saved in AWS) for 2020-06-17
# Finished appending Google API trends data for 2020-06-17
# Getting Google API trends data (saved in AWS) for 2020-06-18
# Finished appending Google API trends data for 2020-06-18
# Getting Google API trends data (saved in AWS) for 2020-06-19
# Finished appending Google API trends data for 2020-06-19
# Getting Google API trends data (saved in AWS) for 2020-06-20
# Finished appending Google API trends data for 2020-06-20
# Getting Google API trends data (saved in AWS) for 2020-06-21
# Finished appending Google API trends data for 2020-06-21
# Getting Google API trends data (saved in AWS) for 2020-06-22
# Finished appending Google API trends data for 2020-06-22
# Getting Google API trends data (saved in AWS) for 2020-06-23
# Finished appending Google API trends data for 2020-06-23
# Getting Google API trends data (saved in AWS) for 2020-06-24
# Finished appending Google API trends data for 2020-06-24
# Getting Google API trends data (saved in AWS) for 2020-06-25
# Finished appending Google API trends data for 2020-06-25
# Getting Google API trends data (saved in AWS) for 2020-06-26
# Finished appending Google API trends data for 2020-06-26
# Getting Google API trends data (saved in AWS) for 2020-06-27
# Finished appending Google API trends data for 2020-06-27
# Getting Google API trends data (saved in AWS) for 2020-06-28
# Finished appending Google API trends data for 2020-06-28
# Getting Google API trends data (saved in AWS) for 2020-06-29
# Finished appending Google API trends data for 2020-06-29
# Getting Google API trends data (saved in AWS) for 2020-06-30
# Finished appending Google API trends data for 2020-06-30
# Getting Google API trends data (saved in AWS) for 2020-07-01
# Finished appending Google API trends data for 2020-07-01
# Getting Google API trends data (saved in AWS) for 2020-07-02
# Finished appending Google API trends data for 2020-07-02
# Getting Google API trends data (saved in AWS) for 2020-07-03
# Finished appending Google API trends data for 2020-07-03
# Getting Google API trends data (saved in AWS) for 2020-07-04
# Finished appending Google API trends data for 2020-07-04
# Getting Google API trends data (saved in AWS) for 2020-07-05
# Finished appending Google API trends data for 2020-07-05
# Getting Google API trends data (saved in AWS) for 2020-07-06
# Finished appending Google API trends data for 2020-07-06
# Getting Google API trends data (saved in AWS) for 2020-07-07
# Finished appending Google API trends data for 2020-07-07
# Getting Google API trends data (saved in AWS) for 2020-07-08
# Finished appending Google API trends data for 2020-07-08
# Getting Google API trends data (saved in AWS) for 2020-07-09
# Finished appending Google API trends data for 2020-07-09
# Getting Google API trends data (saved in AWS) for 2020-07-10
# Finished appending Google API trends data for 2020-07-10
# Getting Google API trends data (saved in AWS) for 2020-07-11
# Finished appending Google API trends data for 2020-07-11
# Getting Google API trends data (saved in AWS) for 2020-07-12
# Finished appending Google API trends data for 2020-07-12
# Getting Google API trends data (saved in AWS) for 2020-07-13
# Finished appending Google API trends data for 2020-07-13
# Getting Google API trends data (saved in AWS) for 2020-07-14
# Finished appending Google API trends data for 2020-07-14
# Getting Google API trends data (saved in AWS) for 2020-07-15
# Finished appending Google API trends data for 2020-07-15
# Getting Google API trends data (saved in AWS) for 2020-07-16
# Finished appending Google API trends data for 2020-07-16
# Getting Google API trends data (saved in AWS) for 2020-07-17
# Finished appending Google API trends data for 2020-07-17
# Getting Google API trends data (saved in AWS) for 2020-07-18
# Finished appending Google API trends data for 2020-07-18
# Getting Google API trends data (saved in AWS) for 2020-07-19
# Finished appending Google API trends data for 2020-07-19
# Getting Google API trends data (saved in AWS) for 2020-07-20
# Finished appending Google API trends data for 2020-07-20
# Getting Google API trends data (saved in AWS) for 2020-07-21
# Finished appending Google API trends data for 2020-07-21
# Getting Google API trends data (saved in AWS) for 2020-07-22
# Finished appending Google API trends data for 2020-07-22
# Getting Google API trends data (saved in AWS) for 2020-07-23
# Finished appending Google API trends data for 2020-07-23
# Getting Google API trends data (saved in AWS) for 2020-07-24
# Finished appending Google API trends data for 2020-07-24
# Getting Google API trends data (saved in AWS) for 2020-07-25
# Finished appending Google API trends data for 2020-07-25
# Getting Google API trends data (saved in AWS) for 2020-07-26
# Finished appending Google API trends data for 2020-07-26
# Getting Google API trends data (saved in AWS) for 2020-07-27
# Finished appending Google API trends data for 2020-07-27
# Getting Google API trends data (saved in AWS) for 2020-07-28
# Finished appending Google API trends data for 2020-07-28
# Getting Google API trends data (saved in AWS) for 2020-07-29
# Finished appending Google API trends data for 2020-07-29
# Getting Google API trends data (saved in AWS) for 2020-07-30
# Finished appending Google API trends data for 2020-07-30
# Getting Google API trends data (saved in AWS) for 2020-07-31
# Finished appending Google API trends data for 2020-07-31
# Getting Google API trends data (saved in AWS) for 2020-08-01
# Finished appending Google API trends data for 2020-08-01
# Getting Google API trends data (saved in AWS) for 2020-08-02
# Finished appending Google API trends data for 2020-08-02
# Getting Google API trends data (saved in AWS) for 2020-08-03
# Finished appending Google API trends data for 2020-08-03
# Getting Google API trends data (saved in AWS) for 2020-08-04
# Finished appending Google API trends data for 2020-08-04
# Getting Google API trends data (saved in AWS) for 2020-08-05
# Finished appending Google API trends data for 2020-08-05
# Getting Google API trends data (saved in AWS) for 2020-08-06
# Finished appending Google API trends data for 2020-08-06
# Getting Google API trends data (saved in AWS) for 2020-08-07
# Finished appending Google API trends data for 2020-08-07
# Getting Google API trends data (saved in AWS) for 2020-08-08
# Finished appending Google API trends data for 2020-08-08
# Getting Google API trends data (saved in AWS) for 2020-08-09
# Finished appending Google API trends data for 2020-08-09
# Getting Google API trends data (saved in AWS) for 2020-08-10
# Finished appending Google API trends data for 2020-08-10
# Getting Google API trends data (saved in AWS) for 2020-08-11
# Finished appending Google API trends data for 2020-08-11
# Getting Google API trends data (saved in AWS) for 2020-08-12
# Finished appending Google API trends data for 2020-08-12
# Getting Google API trends data (saved in AWS) for 2020-08-13
# Finished appending Google API trends data for 2020-08-13
# Getting Google API trends data (saved in AWS) for 2020-08-14
# Finished appending Google API trends data for 2020-08-14
# Getting Google API trends data (saved in AWS) for 2020-08-15
# Finished appending Google API trends data for 2020-08-15
# Getting Google API trends data (saved in AWS) for 2020-08-16
# Finished appending Google API trends data for 2020-08-16
# Getting Google API trends data (saved in AWS) for 2020-08-17
# Finished appending Google API trends data for 2020-08-17
# Getting Google API trends data (saved in AWS) for 2020-08-18
# Finished appending Google API trends data for 2020-08-18
# Getting Google API trends data (saved in AWS) for 2020-08-19
# Finished appending Google API trends data for 2020-08-19
# Getting Google API trends data (saved in AWS) for 2020-08-20
# Finished appending Google API trends data for 2020-08-20
# Getting Google API trends data (saved in AWS) for 2020-08-21
# Finished appending Google API trends data for 2020-08-21
# Getting Google API trends data (saved in AWS) for 2020-08-22
# Finished appending Google API trends data for 2020-08-22
# Getting Google API trends data (saved in AWS) for 2020-08-23
# Finished appending Google API trends data for 2020-08-23
# Getting Google API trends data (saved in AWS) for 2020-08-24
# Finished appending Google API trends data for 2020-08-24
# Getting Google API trends data (saved in AWS) for 2020-08-25
# Finished appending Google API trends data for 2020-08-25
# Getting Google API trends data (saved in AWS) for 2020-08-26
# Finished appending Google API trends data for 2020-08-26
# Getting Google API trends data (saved in AWS) for 2020-08-27
# Finished appending Google API trends data for 2020-08-27
# Getting Google API trends data (saved in AWS) for 2020-08-28
# Finished appending Google API trends data for 2020-08-28
# Getting Google API trends data (saved in AWS) for 2020-08-29
# Finished appending Google API trends data for 2020-08-29
# Getting Google API trends data (saved in AWS) for 2020-08-30
# Finished appending Google API trends data for 2020-08-30
# Getting Google API trends data (saved in AWS) for 2020-08-31
# Finished appending Google API trends data for 2020-08-31
# Getting Google API trends data (saved in AWS) for 2020-09-01
# Finished appending Google API trends data for 2020-09-01
# Getting Google API trends data (saved in AWS) for 2020-09-02
# Finished appending Google API trends data for 2020-09-02
# Getting Google API trends data (saved in AWS) for 2020-09-03
# Finished appending Google API trends data for 2020-09-03
# Getting Google API trends data (saved in AWS) for 2020-09-04
# Finished appending Google API trends data for 2020-09-04
# Getting Google API trends data (saved in AWS) for 2020-09-05
# Finished appending Google API trends data for 2020-09-05
# Getting Google API trends data (saved in AWS) for 2020-09-06
# Finished appending Google API trends data for 2020-09-06
# Getting Google API trends data (saved in AWS) for 2020-09-07
# Finished appending Google API trends data for 2020-09-07
# Getting Google API trends data (saved in AWS) for 2020-09-08
# Finished appending Google API trends data for 2020-09-08
# Getting Google API trends data (saved in AWS) for 2020-09-09
# Finished appending Google API trends data for 2020-09-09
# Getting Google API trends data (saved in AWS) for 2020-09-10
# Finished appending Google API trends data for 2020-09-10
# Getting Google API trends data (saved in AWS) for 2020-09-11
# Finished appending Google API trends data for 2020-09-11
# Getting Google API trends data (saved in AWS) for 2020-09-12
# Finished appending Google API trends data for 2020-09-12
# Getting Google API trends data (saved in AWS) for 2020-09-13
# Finished appending Google API trends data for 2020-09-13
# Getting Google API trends data (saved in AWS) for 2020-09-14
# Finished appending Google API trends data for 2020-09-14
# Getting Google API trends data (saved in AWS) for 2020-09-15
# Finished appending Google API trends data for 2020-09-15
# Getting Google API trends data (saved in AWS) for 2020-09-16
# Finished appending Google API trends data for 2020-09-16
# Getting Google API trends data (saved in AWS) for 2020-09-17
# Finished appending Google API trends data for 2020-09-17
# Getting Google API trends data (saved in AWS) for 2020-09-18
# Finished appending Google API trends data for 2020-09-18
# Getting Google API trends data (saved in AWS) for 2020-09-19
# Finished appending Google API trends data for 2020-09-19
# Getting Google API trends data (saved in AWS) for 2020-09-20
# Finished appending Google API trends data for 2020-09-20
# Getting Google API trends data (saved in AWS) for 2020-09-21
# Finished appending Google API trends data for 2020-09-21
# Getting Google API trends data (saved in AWS) for 2020-09-22
# Finished appending Google API trends data for 2020-09-22
# Getting Google API trends data (saved in AWS) for 2020-09-23
# Finished appending Google API trends data for 2020-09-23
# Getting Google API trends data (saved in AWS) for 2020-09-24
# Finished appending Google API trends data for 2020-09-24
# Getting Google API trends data (saved in AWS) for 2020-09-25
# Finished appending Google API trends data for 2020-09-25
# Getting Google API trends data (saved in AWS) for 2020-09-26
# Finished appending Google API trends data for 2020-09-26
# Getting Google API trends data (saved in AWS) for 2020-09-27
# Finished appending Google API trends data for 2020-09-27
# Getting Google API trends data (saved in AWS) for 2020-09-28
# Finished appending Google API trends data for 2020-09-28
# Getting Google API trends data (saved in AWS) for 2020-09-29
# Finished appending Google API trends data for 2020-09-29
# Getting Google API trends data (saved in AWS) for 2020-09-30
# Finished appending Google API trends data for 2020-09-30
# Getting Google API trends data (saved in AWS) for 2020-10-01
# Finished appending Google API trends data for 2020-10-01
# Getting Google API trends data (saved in AWS) for 2020-10-02
# Finished appending Google API trends data for 2020-10-02
# Getting Google API trends data (saved in AWS) for 2020-10-03
# Finished appending Google API trends data for 2020-10-03
# Getting Google API trends data (saved in AWS) for 2020-10-04
# Finished appending Google API trends data for 2020-10-04
# Getting Google API trends data (saved in AWS) for 2020-10-05
# Finished appending Google API trends data for 2020-10-05
# Getting Google API trends data (saved in AWS) for 2020-10-06
# Finished appending Google API trends data for 2020-10-06
# Getting Google API trends data (saved in AWS) for 2020-10-07
# Finished appending Google API trends data for 2020-10-07
# Getting Google API trends data (saved in AWS) for 2020-10-08
# Finished appending Google API trends data for 2020-10-08
# Getting Google API trends data (saved in AWS) for 2020-10-09
# Finished appending Google API trends data for 2020-10-09
# Getting Google API trends data (saved in AWS) for 2020-10-10
# Finished appending Google API trends data for 2020-10-10
# Getting Google API trends data (saved in AWS) for 2020-10-11
# Finished appending Google API trends data for 2020-10-11
# Getting Google API trends data (saved in AWS) for 2020-10-12
# Finished appending Google API trends data for 2020-10-12
# Getting Google API trends data (saved in AWS) for 2020-10-13
# Finished appending Google API trends data for 2020-10-13
# Getting Google API trends data (saved in AWS) for 2020-10-14
# Finished appending Google API trends data for 2020-10-14
# Getting Google API trends data (saved in AWS) for 2020-10-15
# Finished appending Google API trends data for 2020-10-15
# Getting Google API trends data (saved in AWS) for 2020-10-16
# Finished appending Google API trends data for 2020-10-16
# Getting Google API trends data (saved in AWS) for 2020-10-17
# Finished appending Google API trends data for 2020-10-17
# Getting Google API trends data (saved in AWS) for 2020-10-18
# Finished appending Google API trends data for 2020-10-18
# Getting Google API trends data (saved in AWS) for 2020-10-19
# Finished appending Google API trends data for 2020-10-19
# Getting Google API trends data (saved in AWS) for 2020-10-20
# Finished appending Google API trends data for 2020-10-20
# Getting Google API trends data (saved in AWS) for 2020-10-21
# Finished appending Google API trends data for 2020-10-21
# Getting Google API trends data (saved in AWS) for 2020-10-22
# Finished appending Google API trends data for 2020-10-22
# Getting Google API trends data (saved in AWS) for 2020-10-23
# Finished appending Google API trends data for 2020-10-23
# Getting Google API trends data (saved in AWS) for 2020-10-24
# Finished appending Google API trends data for 2020-10-24
# Getting Google API trends data (saved in AWS) for 2020-10-25
# Finished appending Google API trends data for 2020-10-25
# Getting Google API trends data (saved in AWS) for 2020-10-26
# Finished appending Google API trends data for 2020-10-26
# Getting Google API trends data (saved in AWS) for 2020-10-27
# Finished appending Google API trends data for 2020-10-27
# Getting Google API trends data (saved in AWS) for 2020-10-28
# Finished appending Google API trends data for 2020-10-28
# Getting Google API trends data (saved in AWS) for 2020-10-29
# Finished appending Google API trends data for 2020-10-29
# Getting Google API trends data (saved in AWS) for 2020-10-30
# Finished appending Google API trends data for 2020-10-30
# Getting Google API trends data (saved in AWS) for 2020-10-31
# Finished appending Google API trends data for 2020-10-31
# Getting Google API trends data (saved in AWS) for 2020-11-01
# Finished appending Google API trends data for 2020-11-01
# Getting Google API trends data (saved in AWS) for 2020-11-02
# Finished appending Google API trends data for 2020-11-02
# Getting Google API trends data (saved in AWS) for 2020-11-03
# Finished appending Google API trends data for 2020-11-03
# Getting Google API trends data (saved in AWS) for 2020-11-04
# Finished appending Google API trends data for 2020-11-04
# Getting Google API trends data (saved in AWS) for 2020-11-05
# Finished appending Google API trends data for 2020-11-05
# Getting Google API trends data (saved in AWS) for 2020-11-06
# Finished appending Google API trends data for 2020-11-06
# Getting Google API trends data (saved in AWS) for 2020-11-07
# Finished appending Google API trends data for 2020-11-07
# Getting Google API trends data (saved in AWS) for 2020-11-08
# Finished appending Google API trends data for 2020-11-08
# Getting Google API trends data (saved in AWS) for 2020-11-09
# Finished appending Google API trends data for 2020-11-09
# Getting Google API trends data (saved in AWS) for 2020-11-10
# Finished appending Google API trends data for 2020-11-10
# Getting Google API trends data (saved in AWS) for 2020-11-11
# Finished appending Google API trends data for 2020-11-11
# Getting Google API trends data (saved in AWS) for 2020-11-12
# Finished appending Google API trends data for 2020-11-12
# Getting Google API trends data (saved in AWS) for 2020-11-13
# Finished appending Google API trends data for 2020-11-13
# Getting Google API trends data (saved in AWS) for 2020-11-14
# Finished appending Google API trends data for 2020-11-14
# Getting Google API trends data (saved in AWS) for 2020-11-15
# Finished appending Google API trends data for 2020-11-15
# Getting Google API trends data (saved in AWS) for 2020-11-16
# Finished appending Google API trends data for 2020-11-16
# Getting Google API trends data (saved in AWS) for 2020-11-17
# Finished appending Google API trends data for 2020-11-17
# Getting Google API trends data (saved in AWS) for 2020-11-18
# Finished appending Google API trends data for 2020-11-18
# Getting Google API trends data (saved in AWS) for 2020-11-19
# Finished appending Google API trends data for 2020-11-19
# Getting Google API trends data (saved in AWS) for 2020-11-20
# Finished appending Google API trends data for 2020-11-20
# Getting Google API trends data (saved in AWS) for 2020-11-21
# Finished appending Google API trends data for 2020-11-21
# Getting Google API trends data (saved in AWS) for 2020-11-22
# Finished appending Google API trends data for 2020-11-22
# Getting Google API trends data (saved in AWS) for 2020-11-23
# Finished appending Google API trends data for 2020-11-23
# Getting Google API trends data (saved in AWS) for 2020-11-24
# Finished appending Google API trends data for 2020-11-24
# Getting Google API trends data (saved in AWS) for 2020-11-25
# Finished appending Google API trends data for 2020-11-25
# Getting Google API trends data (saved in AWS) for 2020-11-26
# Finished appending Google API trends data for 2020-11-26
# Getting Google API trends data (saved in AWS) for 2020-11-27
# Finished appending Google API trends data for 2020-11-27
# Getting Google API trends data (saved in AWS) for 2020-11-28
# Finished appending Google API trends data for 2020-11-28
# Getting Google API trends data (saved in AWS) for 2020-11-29
# Finished appending Google API trends data for 2020-11-29
# Getting Google API trends data (saved in AWS) for 2020-11-30
# Finished appending Google API trends data for 2020-11-30
# Getting Google API trends data (saved in AWS) for 2020-12-01
# Finished appending Google API trends data for 2020-12-01
# Getting Google API trends data (saved in AWS) for 2020-12-02
# Finished appending Google API trends data for 2020-12-02
# Getting Google API trends data (saved in AWS) for 2020-12-03
# Finished appending Google API trends data for 2020-12-03
# Getting Google API trends data (saved in AWS) for 2020-12-04
# Finished appending Google API trends data for 2020-12-04
# Getting Google API trends data (saved in AWS) for 2020-12-05
# Finished appending Google API trends data for 2020-12-05
# Getting Google API trends data (saved in AWS) for 2020-12-06
# Finished appending Google API trends data for 2020-12-06
# Getting Google API trends data (saved in AWS) for 2020-12-07
# Finished appending Google API trends data for 2020-12-07
# Getting Google API trends data (saved in AWS) for 2020-12-08
# Finished appending Google API trends data for 2020-12-08
# Getting Google API trends data (saved in AWS) for 2020-12-09
# Finished appending Google API trends data for 2020-12-09
# Getting Google API trends data (saved in AWS) for 2020-12-10
# Finished appending Google API trends data for 2020-12-10
# Getting Google API trends data (saved in AWS) for 2020-12-11
# Finished appending Google API trends data for 2020-12-11
# Getting Google API trends data (saved in AWS) for 2020-12-12
# Finished appending Google API trends data for 2020-12-12
# Getting Google API trends data (saved in AWS) for 2020-12-13
# Finished appending Google API trends data for 2020-12-13
# Getting Google API trends data (saved in AWS) for 2020-12-14
# Finished appending Google API trends data for 2020-12-14
# Getting Google API trends data (saved in AWS) for 2020-12-15
# Finished appending Google API trends data for 2020-12-15
# Getting Google API trends data (saved in AWS) for 2020-12-16
# Finished appending Google API trends data for 2020-12-16
# Getting Google API trends data (saved in AWS) for 2020-12-17
# Finished appending Google API trends data for 2020-12-17
# Getting Google API trends data (saved in AWS) for 2020-12-18
# Finished appending Google API trends data for 2020-12-18
# Getting Google API trends data (saved in AWS) for 2020-12-19
# Finished appending Google API trends data for 2020-12-19
# Getting Google API trends data (saved in AWS) for 2020-12-20
# Finished appending Google API trends data for 2020-12-20
# Getting Google API trends data (saved in AWS) for 2020-12-21
# Finished appending Google API trends data for 2020-12-21
# Getting Google API trends data (saved in AWS) for 2020-12-22
# Finished appending Google API trends data for 2020-12-22
# Getting Google API trends data (saved in AWS) for 2020-12-23
# Finished appending Google API trends data for 2020-12-23
# Getting Google API trends data (saved in AWS) for 2020-12-24
# Finished appending Google API trends data for 2020-12-24
# Getting Google API trends data (saved in AWS) for 2020-12-25
# Finished appending Google API trends data for 2020-12-25
# Getting Google API trends data (saved in AWS) for 2020-12-26
# Finished appending Google API trends data for 2020-12-26
# Getting Google API trends data (saved in AWS) for 2020-12-27
# Finished appending Google API trends data for 2020-12-27
# Getting Google API trends data (saved in AWS) for 2020-12-28
# Finished appending Google API trends data for 2020-12-28
# Getting Google API trends data (saved in AWS) for 2020-12-29
# Finished appending Google API trends data for 2020-12-29
# Getting Google API trends data (saved in AWS) for 2020-12-30
# Finished appending Google API trends data for 2020-12-30
# Getting Google API trends data (saved in AWS) for 2020-12-31
# Finished appending Google API trends data for 2020-12-31
# Getting Google API trends data (saved in AWS) for 2021-01-01
# Finished appending Google API trends data for 2021-01-01
# Getting Google API trends data (saved in AWS) for 2021-01-02
# Finished appending Google API trends data for 2021-01-02
# Getting Google API trends data (saved in AWS) for 2021-01-03
# Finished appending Google API trends data for 2021-01-03
# Getting Google API trends data (saved in AWS) for 2021-01-04
# Finished appending Google API trends data for 2021-01-04
# Getting Google API trends data (saved in AWS) for 2021-01-05
# Finished appending Google API trends data for 2021-01-05
# Getting Google API trends data (saved in AWS) for 2021-01-06
# Finished appending Google API trends data for 2021-01-06
# Getting Google API trends data (saved in AWS) for 2021-01-07
# Finished appending Google API trends data for 2021-01-07
# Getting Google API trends data (saved in AWS) for 2021-01-08
# Finished appending Google API trends data for 2021-01-08
# Getting Google API trends data (saved in AWS) for 2021-01-09
# Finished appending Google API trends data for 2021-01-09
# Getting Google API trends data (saved in AWS) for 2021-01-10
# Finished appending Google API trends data for 2021-01-10
# Getting Google API trends data (saved in AWS) for 2021-01-11
# Finished appending Google API trends data for 2021-01-11
# Getting Google API trends data (saved in AWS) for 2021-01-12
# Finished appending Google API trends data for 2021-01-12
# Getting Google API trends data (saved in AWS) for 2021-01-13
# Finished appending Google API trends data for 2021-01-13
# Getting Google API trends data (saved in AWS) for 2021-01-14
# Finished appending Google API trends data for 2021-01-14
# Getting Google API trends data (saved in AWS) for 2021-01-15
# Finished appending Google API trends data for 2021-01-15
# Getting Google API trends data (saved in AWS) for 2021-01-16
# Finished appending Google API trends data for 2021-01-16
# Getting Google API trends data (saved in AWS) for 2021-01-17
# Finished appending Google API trends data for 2021-01-17
# Getting Google API trends data (saved in AWS) for 2021-01-18
# Finished appending Google API trends data for 2021-01-18
# Getting Google API trends data (saved in AWS) for 2021-01-19
# Finished appending Google API trends data for 2021-01-19
# Getting Google API trends data (saved in AWS) for 2021-01-20
# Finished appending Google API trends data for 2021-01-20
# Getting Google API trends data (saved in AWS) for 2021-01-21
# Finished appending Google API trends data for 2021-01-21
# Getting Google API trends data (saved in AWS) for 2021-01-22
# Finished appending Google API trends data for 2021-01-22
# Getting Google API trends data (saved in AWS) for 2021-01-23
# Finished appending Google API trends data for 2021-01-23
# Getting Google API trends data (saved in AWS) for 2021-01-24
# Finished appending Google API trends data for 2021-01-24
# Getting Google API trends data (saved in AWS) for 2021-01-25
# Finished appending Google API trends data for 2021-01-25
# Getting Google API trends data (saved in AWS) for 2021-01-26
# Finished appending Google API trends data for 2021-01-26
# Getting Google API trends data (saved in AWS) for 2021-01-27
# Finished appending Google API trends data for 2021-01-27
# Getting Google API trends data (saved in AWS) for 2021-01-28
# Finished appending Google API trends data for 2021-01-28
# Getting Google API trends data (saved in AWS) for 2021-01-29
# Finished appending Google API trends data for 2021-01-29
# Getting Google API trends data (saved in AWS) for 2021-01-30
# Finished appending Google API trends data for 2021-01-30
# Getting Google API trends data (saved in AWS) for 2021-01-31
# Finished appending Google API trends data for 2021-01-31
# Getting Google API trends data (saved in AWS) for 2021-02-01
# Error in appending Google API trends data
# An error occurred (404) when calling the HeadObject operation: Not Found
# Error occurred for the following date: 2021-02-01
# Getting Google API trends data (saved in AWS) for 2021-02-02
# Finished appending Google API trends data for 2021-02-02
# Getting Google API trends data (saved in AWS) for 2021-02-03
# Finished appending Google API trends data for 2021-02-03
# Getting Google API trends data (saved in AWS) for 2021-02-04
# Finished appending Google API trends data for 2021-02-04
# Getting Google API trends data (saved in AWS) for 2021-02-05
# Finished appending Google API trends data for 2021-02-05
# Getting Google API trends data (saved in AWS) for 2021-02-06
# Finished appending Google API trends data for 2021-02-06
# Getting Google API trends data (saved in AWS) for 2021-02-07
# Finished appending Google API trends data for 2021-02-07
# Getting Google API trends data (saved in AWS) for 2021-02-08
# Finished appending Google API trends data for 2021-02-08
# Getting Google API trends data (saved in AWS) for 2021-02-09
# Finished appending Google API trends data for 2021-02-09
# Getting Google API trends data (saved in AWS) for 2021-02-10
# Finished appending Google API trends data for 2021-02-10
# Getting Google API trends data (saved in AWS) for 2021-02-11
# Finished appending Google API trends data for 2021-02-11
# Getting Google API trends data (saved in AWS) for 2021-02-12
# Finished appending Google API trends data for 2021-02-12
# Getting Google API trends data (saved in AWS) for 2021-02-13
# Finished appending Google API trends data for 2021-02-13
# Getting Google API trends data (saved in AWS) for 2021-02-14
# Finished appending Google API trends data for 2021-02-14

# %%
time_aggregate_df.tail()
# Out:
#          date covid coronavirus lockdown quarantine vaccine isPartial  \
# 0  2021-02-08   100          13        1          2      51     False
# 0  2021-02-09   100          12        0          2      57     False
# 0  2021-02-10   100          12        1          2      57     False
# 0  2021-02-11   100          12        1          2      63     False
# 0  2021-02-12   100          11        1          2      62     False
#
#   Unnamed: 0
# 0        NaN
# 0        NaN
# 0        NaN
# 0        NaN
# 0        NaN

# %%
region_aggregate_df.tail()
# Out:
#           geoName covid coronavirus lockdown quarantine vaccine        date
# 46       Virginia     0           0        0          0       0  2021-02-14
# 47     Washington     0           0        0          0       0  2021-02-14
# 48  West Virginia     0           0        0          0       0  2021-02-14
# 49      Wisconsin     0           0        0          0       0  2021-02-14
# 50        Wyoming     0           0        0          0       0  2021-02-14

# %% [markdown]
# Export joined dfs

# %%
AGGREGATE_GOOGLE_DIR = "aggregate_google_API_data/"

# %%
# start date
dates_arr[0]
# Out:
# '2020-03-01'

# %%
# end date
dates_arr[-1]
# Out:
# '2021-02-14'

# %%
LOCAL_AGGREGATE_TIME_PATH = LOCAL_SCRAPES_DIR + "aggregate_interest_over_time_"
LOCAL_AGGREGATE_REGION_PATH = LOCAL_SCRAPES_DIR + "aggregate_interest_by_region_"

AWS_AGGREGATE_TIME_PATH = AGGREGATE_GOOGLE_DIR + "aggregate_interest_over_time_"
AWS_AGGREGATE_REGION_PATH = AGGREGATE_GOOGLE_DIR + "aggregate_interest_by_region_"

# %%
DATES_FILENAME = f"{dates_arr[0]}_{dates_arr[-1]}.csv"

# %%
DATES_FILENAME
# Out:
# '2020-03-01_2021-02-14.csv'

# %% [markdown]
# Export locally

# %%
time_aggregate_df.to_csv(LOCAL_AGGREGATE_TIME_PATH + DATES_FILENAME)
region_aggregate_df.to_csv(LOCAL_AGGREGATE_REGION_PATH + DATES_FILENAME)

# %% [markdown]
# Export to AWS

# %%
s3.upload_file(LOCAL_AGGREGATE_TIME_PATH + DATES_FILENAME, AWS_BUCKET, AWS_AGGREGATE_TIME_PATH + DATES_FILENAME)
s3.upload_file(LOCAL_AGGREGATE_REGION_PATH + DATES_FILENAME, AWS_BUCKET, AWS_AGGREGATE_REGION_PATH + DATES_FILENAME)

# %% [markdown]
# Remove local versions

# %%
os.remove(LOCAL_AGGREGATE_TIME_PATH + DATES_FILENAME)
os.remove(LOCAL_AGGREGATE_REGION_PATH + DATES_FILENAME)
