# %% [markdown]
# # Purpose of script
#
# The purpose of the script is to get to know the Google Trends API
#
# I'll be using a wrapper Python package (`pytrends`) to interface with the API
#
# https://pypi.org/project/pytrends/
#
# https://github.com/GeneralMills/pytrends
#
# Note: This package (`pytrends`) may not be up to date because it's not an official Google Trends API and since Google constantly updates their backend, it's likely that these scripts will have to change.
#
# Another generally helpful resource: https://www.holisticseo.digital/python-seo/google-trends/

# %%
import os
import pandas as pd
import pytrends
from pytrends.request import TrendReq
import datetime
import boto3

# %% [markdown]
# ### Initialize API

# %%
pytrends_API = TrendReq()

# %% [markdown]
# ### Look for particular keywords
#
# Some terms to look up
#
# 1. covid/covid19
# 2. coronavirus
# 3. lockdown
# 4. quarantine
# 5. shutdown
# 6. vaccine
#
# Note: The API only lets us have 5 keywords at a time

# %%
keywords = ["covid", "coronavirus", "lockdown", "quarantine", "vaccine"]

# %%
pytrends_API.build_payload(kw_list = keywords, geo = "US")

# %% [markdown]
# #### Look up prevalence of keywords, by region
#
# The values are calculated on a scale from 0 to 100, where 100 is the location with the most popularity as a fraction of total searches in that location, a value of 50 indicates a location which is half as popular. A value of 0 indicates a location where there was not enough data for this term.

# %%
interest_by_state = pytrends_API.interest_by_region()

# %%
interest_by_state.head(20)
# Out:
#                       covid  coronavirus  lockdown  quarantine  vaccine
# geoName
# Alabama                  40           50         1           2        7
# Alaska                   50           40         0           2        8
# Arizona                  43           46         1           2        8
# Arkansas                 43           47         1           2        7
# California               41           47         2           2        8
# Colorado                 45           45         1           2        7
# Connecticut              43           45         1           3        8
# Delaware                 41           47         1           2        9
# District of Columbia     39           46         1           3       11
# Florida                  40           48         1           2        9
# Georgia                  41           48         1           2        8
# Hawaii                   43           44         1           5        7
# Idaho                    40           51         1           1        7
# Illinois                 43           45         2           2        8
# Indiana                  43           46         1           2        8
# Iowa                     45           46         1           1        7
# Kansas                   42           46         1           3        8
# Kentucky                 45           44         1           2        8
# Louisiana                40           49         1           2        8
# Maine                    44           46         1           2        7

# %%
pytrends_API.interest_over_time()
# Out:
#             covid  coronavirus  lockdown  quarantine  vaccine isPartial
# date
# 2016-02-14      0            0         0           0        0     False
# 2016-02-21      0            0         0           0        0     False
# 2016-02-28      0            0         0           0        0     False
# 2016-03-06      0            0         0           0        0     False
# 2016-03-13      0            0         0           0        0     False
# ...           ...          ...       ...         ...      ...       ...
# 2021-01-10     23            3         0           0       10     False
# 2021-01-17     22            3         0           0       10     False
# 2021-01-24     22            3         0           0       10     False
# 2021-01-31     19            2         0           0       10     False
# 2021-02-07     15            2         0           0        7      True
#
# [261 rows x 6 columns]

# %% [markdown]
# ### Modify timeframe of search
#
# Seems like we can also specify, via the `timeframe` parameter, the time period for our search.
#
# https://github.com/GeneralMills/pytrends/issues/211
#
# Example trends link: https://trends.google.com/trends/explore?date=2021-01-10%202021-01-11&geo=US&q=%2Fm%2F0dl567,%2Fm%2F0261x8t

# %% [markdown]
# Example: Look for searches between 2020-03-20 and 2020-03-22

# %%
pytrends_API.build_payload(kw_list = keywords, geo = "US", timeframe = "2020-03-20 2020-03-22")

# %%
pytrends_API.interest_over_time()
# Out:
#             covid  coronavirus  lockdown  quarantine  vaccine  isPartial
# date
# 2020-03-20     24           99        10           5        1      False
# 2020-03-21     23           96         5           4        1      False
# 2020-03-22     25          100         6           4        1      False

# %%
pytrends_API.interest_by_region().head()
# Out:
#             covid  coronavirus  lockdown  quarantine  vaccine
# geoName
# Alabama        19           77         2           2        0
# Alaska         26           68         3           3        0
# Arizona        18           75         4           3        0
# Arkansas       20           73         4           2        1
# California     18           70         8           4        0

# %% [markdown]
# ### Can we get both location and time?
#
# We can get a breakdown of search trends by region/state and by time, but can we do both at the same time? For example, can we see the day-by-day breakdown of searches in, say, California?

# %%
pytrends_API.build_payload(kw_list = keywords, geo = "US")

# %% [markdown]
# Can we do this approach for one day at a time?

# %%
pytrends_API.build_payload(kw_list = keywords, geo = "US", timeframe = "2020-03-20 2020-03-20")

# %%
pytrends_API.interest_over_time()
# Out:
#             covid  coronavirus  lockdown  quarantine  vaccine  isPartial
# date
# 2020-03-20     25          100        10           5        1      False

# %%
pytrends_API.interest_by_region()
# Out:
#                       covid  coronavirus  lockdown  quarantine  vaccine
# geoName
# Alabama                  19           76         2           3        0
# Alaska                   28           66         3           3        0
# Arizona                  19           72         6           3        0
# Arkansas                 20           74         2           3        1
# California               18           65        13           4        0
# Colorado                 21           70         5           4        0
# Connecticut              16           77         5           2        0
# Delaware                 16           73         7           4        0
# District of Columbia     22           72         3           2        1
# Florida                  15           77         5           3        0
# Georgia                  17           75         4           4        0
# Hawaii                   20           71         3           5        1
# Idaho                    19           73         5           3        0
# Illinois                 18           64        15           3        0
# Indiana                  16           74         6           4        0
# Iowa                     22           71         4           3        0
# Kansas                   19           70         7           4        0
# Kentucky                 19           72         5           4        0
# Louisiana                15           77         5           3        0
# Maine                    21           75         2           2        0
# Maryland                 15           76         5           3        1
# Massachusetts            17           71         9           3        0
# Michigan                 17           73         7           3        0
# Minnesota                24           67         7           2        0
# Mississippi              15           78         3           4        0
# Missouri                 21           71         4           4        0
# Montana                  21           74         1           2        2
# Nebraska                 23           73         2           2        0
# Nevada                   15           74         7           4        0
# New Hampshire            24           68         5           2        1
# New Jersey               14           78         6           2        0
# New Mexico               19           76         2           2        1
# New York                 15           75         7           3        0
# North Carolina           18           75         4           3        0
# North Dakota             22           72         3           2        1
# Ohio                     17           76         5           2        0
# Oklahoma                 21           70         5           3        1
# Oregon                   22           68         6           4        0
# Pennsylvania             17           76         4           3        0
# Rhode Island             18           72         9           1        0
# South Carolina           15           79         4           2        0
# South Dakota             25           70         1           2        2
# Tennessee                18           75         4           3        0
# Texas                    18           72         6           4        0
# Utah                     21           71         4           4        0
# Vermont                  24           71         3           1        1
# Virginia                 18           75         4           3        0
# Washington               21           67         9           3        0
# West Virginia            18           79         1           2        0
# Wisconsin                20           69         8           3        0
# Wyoming                  22           72         1           4        1

# %% [markdown]
# ### General approach
#
# We can adopt a looping approach, where we can query by day and get each state's value in the `interest_by_region` request call for that day.
#
# Let's start our search at `2020-03-01` (March 1st, 2020) and go up `2021-02-01` (February 1st, 2021). In the actual script, we'd just change the endpoint. This link explains how to create a range of dates: https://www.kite.com/python/answers/how-to-create-a-range-of-dates-in-python
#
# For each query, we can save it as a df and then upload that df to AWS

# %% [markdown]
# #### Initialize API, get keywords

# %%
pytrends_API = TrendReq()

# %%
keywords = ["covid", "coronavirus", "lockdown", "quarantine", "vaccine"]

# %% [markdown]
# #### Get array of dates

# %%
start_date = datetime.date(2020, 3, 1)
end_date = datetime.date(2021, 2, 1)
total_num_dates = (end_date - start_date).days

# %%
dates_arr = []

# %%
for day in range(total_num_dates):
    new_date = (start_date + datetime.timedelta(days = day)).isoformat()
    dates_arr.append(new_date)

# %% [markdown]
# #### Get payload
#
# Here's an example script detailing how to get the payload, with a custom set of keywords and a single date
#
# `pytrends_API.build_payload(kw_list = keywords, geo = "US", timeframe = "2020-03-20 2020-03-20")`

# %%
pytrends_API.build_payload(kw_list = keywords, geo = "US", timeframe = "2020-03-20 2020-03-20")

# %%
pytrends_API.interest_over_time()
# Out:
#             covid  coronavirus  lockdown  quarantine  vaccine  isPartial
# date
# 2020-03-20     25          100        10           5        1      False

# %%
pytrends_API.interest_by_region()
# Out:
#                       covid  coronavirus  lockdown  quarantine  vaccine
# geoName
# Alabama                  19           76         2           3        0
# Alaska                   28           66         3           3        0
# Arizona                  19           72         6           3        0
# Arkansas                 20           74         2           3        1
# California               18           65        13           4        0
# Colorado                 21           70         5           4        0
# Connecticut              16           77         5           2        0
# Delaware                 16           73         7           4        0
# District of Columbia     22           72         3           2        1
# Florida                  15           77         5           3        0
# Georgia                  17           75         4           4        0
# Hawaii                   20           71         3           5        1
# Idaho                    19           73         5           3        0
# Illinois                 18           64        15           3        0
# Indiana                  16           74         6           4        0
# Iowa                     22           71         4           3        0
# Kansas                   19           70         7           4        0
# Kentucky                 19           72         5           4        0
# Louisiana                15           77         5           3        0
# Maine                    21           75         2           2        0
# Maryland                 15           76         5           3        1
# Massachusetts            17           71         9           3        0
# Michigan                 17           73         7           3        0
# Minnesota                24           67         7           2        0
# Mississippi              15           78         3           4        0
# Missouri                 21           71         4           4        0
# Montana                  21           74         1           2        2
# Nebraska                 23           73         2           2        0
# Nevada                   15           74         7           4        0
# New Hampshire            24           68         5           2        1
# New Jersey               14           78         6           2        0
# New Mexico               19           76         2           2        1
# New York                 15           75         7           3        0
# North Carolina           18           75         4           3        0
# North Dakota             22           72         3           2        1
# Ohio                     17           76         5           2        0
# Oklahoma                 21           70         5           3        1
# Oregon                   22           68         6           4        0
# Pennsylvania             17           76         4           3        0
# Rhode Island             18           72         9           1        0
# South Carolina           15           79         4           2        0
# South Dakota             25           70         1           2        2
# Tennessee                18           75         4           3        0
# Texas                    18           72         6           4        0
# Utah                     21           71         4           4        0
# Vermont                  24           71         3           1        1
# Virginia                 18           75         4           3        0
# Washington               21           67         9           3        0
# West Virginia            18           79         1           2        0
# Wisconsin                20           69         8           3        0
# Wyoming                  22           72         1           4        1

# %% [markdown]
# #### Create script
#
# Let's loop through all the dates, query the API by those dates, get the `interest_over_time` and `interest_by_region` values, and export to AWs

# %% [markdown]
# Log into AWS

# %%
AWS_BUCKET = os.environ["AWS_BUCKET"]
AWS_ACCESS = os.environ["AWS_ACCESS"]
AWS_SECRET = os.environ["AWS_SECRET"]

# %%
s3 = boto3.client('s3',
                  aws_access_key_id=AWS_ACCESS,
                  aws_secret_access_key=AWS_SECRET)

# %% [markdown]
# Get paths to save file locally and in AWS

# %%
FRESH_SCRAPES_FILENAME = ""
INTEREST_OVER_TIME_FILENAME = "interest_over_time_"
INTEREST_BY_REGION_FILENAME = "interest_by_region_"

# %%
LOCAL_SCRAPES_DIR = "../../../tweets/google_API_scrapes/"
AWS_SCRAPES_DIR = "google_API_scrapes/"

LOCAL_TIME_FILENAME = LOCAL_SCRAPES_DIR + INTEREST_OVER_TIME_FILENAME
LOCAL_REGION_FILENAME = LOCAL_SCRAPES_DIR + INTEREST_BY_REGION_FILENAME

AWS_TIME_FILENAME = AWS_SCRAPES_DIR + INTEREST_OVER_TIME_FILENAME
AWS_REGION_FILENAME = AWS_SCRAPES_DIR + INTEREST_BY_REGION_FILENAME

# %% [markdown]
# #### Create loop

# %%
pytrends_API = TrendReq()

# %%
keywords = ["covid", "coronavirus", "lockdown", "quarantine", "vaccine"]

# %%
for date in dates_arr:
    
    try:
        
        print(f"Getting Google API trends data for {date}")
        
        pytrends_API = TrendReq()

        # build payload
        pytrends_API.build_payload(kw_list = keywords, geo = "US", timeframe = f"{date} {date}")

        # get trends over time and by region, and export locally:
        pytrends_API.interest_over_time().to_csv(LOCAL_TIME_FILENAME + date + ".csv")
        pytrends_API.interest_by_region().to_csv(LOCAL_REGION_FILENAME + date + ".csv")

        # upload to AWS
        s3.upload_file(LOCAL_TIME_FILENAME + date + ".csv", AWS_BUCKET, AWS_TIME_FILENAME + date + ".csv")
        s3.upload_file(LOCAL_REGION_FILENAME + date + ".csv", AWS_BUCKET, AWS_REGION_FILENAME + date + ".csv")

        # delete local versions of the file
        os.remove(LOCAL_TIME_FILENAME + date + ".csv")
        os.remove(LOCAL_REGION_FILENAME + date + ".csv")
        
        print(f"Finished getting Google API trends data for {date}")
        
    except Exception as e:
        print("Error in getting Google API trends data")
        print(e)
        print(f"Error occurred for the following date: {date}")
# Out:
# Getting Google API trends data for 2020-03-01
# Finished getting Google API trends data for 2020-03-01
# Getting Google API trends data for 2020-03-02
# Finished getting Google API trends data for 2020-03-02
# Getting Google API trends data for 2020-03-03
# Finished getting Google API trends data for 2020-03-03
# Getting Google API trends data for 2020-03-04
# Finished getting Google API trends data for 2020-03-04
# Getting Google API trends data for 2020-03-05
# Finished getting Google API trends data for 2020-03-05
# Getting Google API trends data for 2020-03-06
# Finished getting Google API trends data for 2020-03-06
# Getting Google API trends data for 2020-03-07
# Finished getting Google API trends data for 2020-03-07
# Getting Google API trends data for 2020-03-08
# Finished getting Google API trends data for 2020-03-08
# Getting Google API trends data for 2020-03-09
# Finished getting Google API trends data for 2020-03-09
# Getting Google API trends data for 2020-03-10
# Finished getting Google API trends data for 2020-03-10
# Getting Google API trends data for 2020-03-11
# Finished getting Google API trends data for 2020-03-11
# Getting Google API trends data for 2020-03-12
# Finished getting Google API trends data for 2020-03-12
# Getting Google API trends data for 2020-03-13
# Finished getting Google API trends data for 2020-03-13
# Getting Google API trends data for 2020-03-14
# Finished getting Google API trends data for 2020-03-14
# Getting Google API trends data for 2020-03-15
# Finished getting Google API trends data for 2020-03-15
# Getting Google API trends data for 2020-03-16
# Finished getting Google API trends data for 2020-03-16
# Getting Google API trends data for 2020-03-17
# Finished getting Google API trends data for 2020-03-17
# Getting Google API trends data for 2020-03-18
# Finished getting Google API trends data for 2020-03-18
# Getting Google API trends data for 2020-03-19
# Finished getting Google API trends data for 2020-03-19
# Getting Google API trends data for 2020-03-20
# Finished getting Google API trends data for 2020-03-20
# Getting Google API trends data for 2020-03-21
# Finished getting Google API trends data for 2020-03-21
# Getting Google API trends data for 2020-03-22
# Finished getting Google API trends data for 2020-03-22
# Getting Google API trends data for 2020-03-23
# Finished getting Google API trends data for 2020-03-23
# Getting Google API trends data for 2020-03-24
# Finished getting Google API trends data for 2020-03-24
# Getting Google API trends data for 2020-03-25
# Finished getting Google API trends data for 2020-03-25
# Getting Google API trends data for 2020-03-26
# Finished getting Google API trends data for 2020-03-26
# Getting Google API trends data for 2020-03-27
# Finished getting Google API trends data for 2020-03-27
# Getting Google API trends data for 2020-03-28
# Finished getting Google API trends data for 2020-03-28
# Getting Google API trends data for 2020-03-29
# Finished getting Google API trends data for 2020-03-29
# Getting Google API trends data for 2020-03-30
# Finished getting Google API trends data for 2020-03-30
# Getting Google API trends data for 2020-03-31
# Finished getting Google API trends data for 2020-03-31
# Getting Google API trends data for 2020-04-01
# Finished getting Google API trends data for 2020-04-01
# Getting Google API trends data for 2020-04-02
# Finished getting Google API trends data for 2020-04-02
# Getting Google API trends data for 2020-04-03
# Finished getting Google API trends data for 2020-04-03
# Getting Google API trends data for 2020-04-04
# Finished getting Google API trends data for 2020-04-04
# Getting Google API trends data for 2020-04-05
# Finished getting Google API trends data for 2020-04-05
# Getting Google API trends data for 2020-04-06
# Finished getting Google API trends data for 2020-04-06
# Getting Google API trends data for 2020-04-07
# Finished getting Google API trends data for 2020-04-07
# Getting Google API trends data for 2020-04-08
# Finished getting Google API trends data for 2020-04-08
# Getting Google API trends data for 2020-04-09
# Finished getting Google API trends data for 2020-04-09
# Getting Google API trends data for 2020-04-10
# Finished getting Google API trends data for 2020-04-10
# Getting Google API trends data for 2020-04-11
# Finished getting Google API trends data for 2020-04-11
# Getting Google API trends data for 2020-04-12
# Finished getting Google API trends data for 2020-04-12
# Getting Google API trends data for 2020-04-13
# Finished getting Google API trends data for 2020-04-13
# Getting Google API trends data for 2020-04-14
# Finished getting Google API trends data for 2020-04-14
# Getting Google API trends data for 2020-04-15
# Finished getting Google API trends data for 2020-04-15
# Getting Google API trends data for 2020-04-16
# Finished getting Google API trends data for 2020-04-16
# Getting Google API trends data for 2020-04-17
# Finished getting Google API trends data for 2020-04-17
# Getting Google API trends data for 2020-04-18
# Finished getting Google API trends data for 2020-04-18
# Getting Google API trends data for 2020-04-19
# Finished getting Google API trends data for 2020-04-19
# Getting Google API trends data for 2020-04-20
# Finished getting Google API trends data for 2020-04-20
# Getting Google API trends data for 2020-04-21
# Finished getting Google API trends data for 2020-04-21
# Getting Google API trends data for 2020-04-22
# Finished getting Google API trends data for 2020-04-22
# Getting Google API trends data for 2020-04-23
# Finished getting Google API trends data for 2020-04-23
# Getting Google API trends data for 2020-04-24
# Finished getting Google API trends data for 2020-04-24
# Getting Google API trends data for 2020-04-25
# Finished getting Google API trends data for 2020-04-25
# Getting Google API trends data for 2020-04-26
# Finished getting Google API trends data for 2020-04-26
# Getting Google API trends data for 2020-04-27
# Finished getting Google API trends data for 2020-04-27
# Getting Google API trends data for 2020-04-28
# Finished getting Google API trends data for 2020-04-28
# Getting Google API trends data for 2020-04-29
# Finished getting Google API trends data for 2020-04-29
# Getting Google API trends data for 2020-04-30
# Finished getting Google API trends data for 2020-04-30
# Getting Google API trends data for 2020-05-01
# Finished getting Google API trends data for 2020-05-01
# Getting Google API trends data for 2020-05-02
# Finished getting Google API trends data for 2020-05-02
# Getting Google API trends data for 2020-05-03
# Finished getting Google API trends data for 2020-05-03
# Getting Google API trends data for 2020-05-04
# Finished getting Google API trends data for 2020-05-04
# Getting Google API trends data for 2020-05-05
# Finished getting Google API trends data for 2020-05-05
# Getting Google API trends data for 2020-05-06
# Finished getting Google API trends data for 2020-05-06
# Getting Google API trends data for 2020-05-07
# Finished getting Google API trends data for 2020-05-07
# Getting Google API trends data for 2020-05-08
# Finished getting Google API trends data for 2020-05-08
# Getting Google API trends data for 2020-05-09
# Finished getting Google API trends data for 2020-05-09
# Getting Google API trends data for 2020-05-10
# Finished getting Google API trends data for 2020-05-10
# Getting Google API trends data for 2020-05-11
# Finished getting Google API trends data for 2020-05-11
# Getting Google API trends data for 2020-05-12
# Finished getting Google API trends data for 2020-05-12
# Getting Google API trends data for 2020-05-13
# Finished getting Google API trends data for 2020-05-13
# Getting Google API trends data for 2020-05-14
# Finished getting Google API trends data for 2020-05-14
# Getting Google API trends data for 2020-05-15
# Finished getting Google API trends data for 2020-05-15
# Getting Google API trends data for 2020-05-16
# Finished getting Google API trends data for 2020-05-16
# Getting Google API trends data for 2020-05-17
# Finished getting Google API trends data for 2020-05-17
# Getting Google API trends data for 2020-05-18
# Finished getting Google API trends data for 2020-05-18
# Getting Google API trends data for 2020-05-19
# Finished getting Google API trends data for 2020-05-19
# Getting Google API trends data for 2020-05-20
# Finished getting Google API trends data for 2020-05-20
# Getting Google API trends data for 2020-05-21
# Finished getting Google API trends data for 2020-05-21
# Getting Google API trends data for 2020-05-22
# Finished getting Google API trends data for 2020-05-22
# Getting Google API trends data for 2020-05-23
# Finished getting Google API trends data for 2020-05-23
# Getting Google API trends data for 2020-05-24
# Finished getting Google API trends data for 2020-05-24
# Getting Google API trends data for 2020-05-25
# Finished getting Google API trends data for 2020-05-25
# Getting Google API trends data for 2020-05-26
# Finished getting Google API trends data for 2020-05-26
# Getting Google API trends data for 2020-05-27
# Finished getting Google API trends data for 2020-05-27
# Getting Google API trends data for 2020-05-28
# Finished getting Google API trends data for 2020-05-28
# Getting Google API trends data for 2020-05-29
# Finished getting Google API trends data for 2020-05-29
# Getting Google API trends data for 2020-05-30
# Finished getting Google API trends data for 2020-05-30
# Getting Google API trends data for 2020-05-31
# Finished getting Google API trends data for 2020-05-31
# Getting Google API trends data for 2020-06-01
# Finished getting Google API trends data for 2020-06-01
# Getting Google API trends data for 2020-06-02
# Finished getting Google API trends data for 2020-06-02
# Getting Google API trends data for 2020-06-03
# Finished getting Google API trends data for 2020-06-03
# Getting Google API trends data for 2020-06-04
# Finished getting Google API trends data for 2020-06-04
# Getting Google API trends data for 2020-06-05
# Finished getting Google API trends data for 2020-06-05
# Getting Google API trends data for 2020-06-06
# Finished getting Google API trends data for 2020-06-06
# Getting Google API trends data for 2020-06-07
# Finished getting Google API trends data for 2020-06-07
# Getting Google API trends data for 2020-06-08
# Finished getting Google API trends data for 2020-06-08
# Getting Google API trends data for 2020-06-09
# Finished getting Google API trends data for 2020-06-09
# Getting Google API trends data for 2020-06-10
# Finished getting Google API trends data for 2020-06-10
# Getting Google API trends data for 2020-06-11
# Finished getting Google API trends data for 2020-06-11
# Getting Google API trends data for 2020-06-12
# Finished getting Google API trends data for 2020-06-12
# Getting Google API trends data for 2020-06-13
# Finished getting Google API trends data for 2020-06-13
# Getting Google API trends data for 2020-06-14
# Finished getting Google API trends data for 2020-06-14
# Getting Google API trends data for 2020-06-15
# Finished getting Google API trends data for 2020-06-15
# Getting Google API trends data for 2020-06-16
# Finished getting Google API trends data for 2020-06-16
# Getting Google API trends data for 2020-06-17
# Finished getting Google API trends data for 2020-06-17
# Getting Google API trends data for 2020-06-18
# Finished getting Google API trends data for 2020-06-18
# Getting Google API trends data for 2020-06-19
# Finished getting Google API trends data for 2020-06-19
# Getting Google API trends data for 2020-06-20
# Finished getting Google API trends data for 2020-06-20
# Getting Google API trends data for 2020-06-21
# Finished getting Google API trends data for 2020-06-21
# Getting Google API trends data for 2020-06-22
